# %%
def train_markov_chain(lyrics):
    """
    Args:
      - lyrics: a list of strings, where each string represents
                the lyrics of one song by an artist.
    
    Returns:
      A dict that maps a single word ("unigram") to a list of
      words that follow that word, representing the Markov
      chain trained on the lyrics.
    """
    chain = {"<START>": []}
    for lyric in lyrics:
        words = lyric.replace("\n", ' <N> ').strip().split(' ')
        chain["<START>"].append(words[0])
        chain[words[0]] = []
        prev_word = words[0]
        for word in words[1:len(words)-1]:
            if prev_word not in chain.keys():
                chain[prev_word] = []
            chain[prev_word].append(word)
            prev_word = word
        if word not in chain.keys():
            chain[word] = []
        chain[word].append("<END>")
    return chain

# %%
# Load the pickled lyrics object that you created in Lab A.
import pickle
lyrics = pickle.load(open("lyrics.pkl", "rb"))

# Call the function you wrote above.
chain = train_markov_chain(lyrics)

# What words tend to start a song (i.e., what words follow the <START> tag?)
#print(chain["<START>"])

# What words tend to begin a line (i.e., what words follow the line break tag?)
#print(chain["<N>"][:20])

# %%
import random

def generate_new_lyrics(chain):
    """
    Args:
      - chain: a dict representing the Markov chain,
               such as one generated by generate_new_lyrics()
    
    Returns:
      A string representing the randomly generated song.
    """
    
    # a list for storing the generated words
    words = []
    # generate the first word
    words.append(random.choice(chain["<START>"]))
    i = 0
    while True: 
        currentWord = words[i]
        if currentWord == "<END>": 
            break
        words.append(random.choice(chain[currentWord]))
        i+=1
        
    # join the words together into a string with line breaks
    lyrics = " ".join(words[:-1])
    return "\n".join(lyrics.split("<N>"))

# %%
print(generate_new_lyrics(chain))
# Out:
# I don't be reppin' Young Sinatra clique, God
#  Spoke about music we always gotta get up, wait a the fame (Bounce)
#  I was taken literally in the fam, for thought, yeah I was on the ghetto
#  You in blood
#  I told what I said they all this
#  Nobody knows what I run that
#  My mind right here since you know me
#  I ain't black, feel like
#  And they got stabbed by the ground, the very same thing, so your dreams
#  Spoke about this ain't ashamed to push through that shit
#  Just wanna blame it back, take you whyIt's the city with the trophySince Hawaiian Sophie
#  Mass choir
#  Theres a little Bobby just fight, for the groupie bitches
#  We got my contraption (Bobby)
#  They probably have some more and when I'm so I change of the day boy went from the reason)
#  I keep breathing my time to act white manAt the reincarnated Young boy, a'ight boy?
#  God
#  Time is Young Sinatra what it and then what they got that trap
#  They gon' fuck with a goddamn king
#  Let me like everybody gon' forgive 'em
#  I do not more into my mind in the lift of shit is me what to the casino
#  Depends the shit
#  God damned, go investigating shit, just cause my son, my name?
#  I wrote this event
#  It feel like villains
#  Depends the brink of auto tune like my time passing me to notice happiness
#  Theres a look a brother is the first thing from two traits
#  They know my soul into your soul glow
#  Cause all I am ravaged with that I be a while haters screaming "I knew it way back again
#  Judging the
#  You do what we could write this
#  It feel like (oh God)
#  We can you in a fun to the mansion
#  Spoke about you never cumming like it like, like
#  They probably wonder why)We get up, get high
#  They know, how to when I am
#  You'd rather not a man right
#  He always do really wanted me fatality yeah I would call
#  Just start to the night I don't wanna bring it
#  I would lie
#  My flow delicious, bounty huntin' like to recede
#  We real as my homies and a sound repetitiveHatin' in the arm
#  Spoke about that have and Donald trump is you feel the back to gift that so hard sometimes
#  They can't fail
#  And if I read about a sick I was in the person I would be a million dollars
#  God damn, this bitch
#  Spoke about
#  Mass choir
#  I was
#  They can't pronounce I'm smoking that you die)
#  Spoke about Logic, not know
#  I began to be right
#  I can relate?
#  We get you better inspect the boss
#  Pretend that
#  Rap, bitches, money, weed
#  I don't know why you listening, I was trying to be doing
#  But I read this I am I, so y'all ready for the cream, you mine was anxiety to me
#  And how in time and fuck with meFar away with me
#  Spoke about it like everything's all the gas, you know where you're raw denim, my enemy and I give a quarter through a serpent to the next to this feeling, this shit
#  Spoke about mineI've been runnin' round
#  Spoke about sleeping outside, outside
#  I was safe, I wish you down
#  Depends the symphony
#  Even though the fuck
#  God on indica
#  They won't ever wanted me
#  I am right
#  God damn
#  And maybe it'll live is what I know I've been at it back in
#  I was broke is retro
#  Than that
#  I said I gotta die
#  But come and crime
#  Judging rap
#  Let me
#  I call that at war and my
#  Pretend to wonder what I'm livin' in a change
#  Sunday morning getting higher than vamonos
#  I got it my God damned, go down the days
#  Reefer to the beat her
#  I have been through that messageYou got it, my vision, can't take it
#  My chain, my homies, I began to be embarrassed if I was born with my hair
#  Let me
#  Sunday morning and raised in there for the meaning of my mind and feel
#  They riding with no bread, no Bobby, I would love and choose
#  They know I do an addict
#  Let him like this world I live, I remember where was a song
#  Judging rap shit
#  We can relate to a family then hit
#  I don't gotta like everybody need to reminisce when the trunk
#  I got a reason
#  God
#  God
#  Let me
#  Nobody gotta' agree with this grain, simple
#  Depends the track
#  But my mind
#  Hold up, get it way to have interfered with his toys
#  I can go
#  Let me I remember somehow, someway
#  I gotta let everybody hatin' on some shit is merely an Uzi
#  My name until the devil in life sentence
#  So black
#  Nobody understands
#  Spoke about commas in my dresser, I'm just fine
#  You'd rather not manic, bitch
#  Pretend to your dreams supposed to bust rhymes
#  Just be smoking so I am in
#  Pretend to 5 tourettes
#  Spoke about it now
#  Cause if I'll be Black people that it's the shade in the fact it's been on
#  My mind playing nigga daddy
#  I began to be asking, I am in life
#  I once was just as I'm in 'em, no good but nobody care about that, everything that ain't free
#  God as quick as angry at me
#  Like, like a debt in the dream, can I got, I'm living a gun to meet and innovate it but you don't even got no love you can't follow like you know
#  My God
#  Judging the bitch and sisters
#  I can I was fine wine while the very moment
#  Reefer to pop shop
#  Depends the science of my daddy beat it for the blue, so hard to get it
#  So everyone else's. So I said that
#  With my skin mothafucka I'm driving, (I said - no matter what you a hike like oh my, my, I knew it!"
#  Mass choir
#  God don't wanna know, I stood next man
#  Like, like naw man, if I remember somehow, someway
#  He always gotta do you
#  And fuck all about the seven days and I can't fight
#  I was anxiety is my zeros beyond Jay
#  And even step back then abide it out there, I been inconsistent
#  They see my day
#  Time unknown. The Chronicles of the reason)
#  Out the real as, real you
#  We get it back
#  God
#  Doesn't mean Spiderman should know I don't we share the fame
#  But he said, shit you ever been, where am livin' like me and violence in the gang, we are going.
#  But not a come at first
#  So enjoy the fourth album was asking me and now
#  They gon' fuck you are, where they caskets
#  Nobody can give a novel, starrin' in life is imma die all my momma got no matter
#  Time of pacing, I don't wanna get it trueOut the vibe
#  I remember me? I'll take it
#  With hopes of that I wrote this fucking with the ground for the nation that did I knew that magician pull up
#  I live, I been
#  I run
#  You get it on the end what we go, permission of the phone
#  Damn, it logically
#  I do without self-respect
#  So cold
#  You gon' run that I would you know my body seep in time
#  So I wish that wrist
#  I think that shit is too hot tub
#  With a young'n on this that
#  Time unknown. The Godfather, the mic in my house, you look a killing spree
#  You gon' fuck you don't know it's a nigger
#  Rap, bitches, money, that I've said these bitches say you feeling under pressureHey, son, my house if pro is unseen
#  She was raised in the coca
#  So live
#  Depends the worker just might catch a white bullshit was the shipWhat?CopyI'm receiving audio embedded in the weak
#  I am I was smokin crack to say shit with that new-new in the police!
#  And her in the kitchen over here for I got it
#  My mind and let it goin' on
#  He always saw ya life for thought
#  They know that revision
#  Spoke about this
#  You need a son (ayy)
#  Spoke about this that real as a child?
#  They was engulfed with category 5 tourettes
#  We build a slave to a fuck around with me)(Pop bottles with every day
#  Pretend that let fame ho
#  Spoke about what's up, wassup, get off a dent in the boy anymore
#  Like, like to the realest the world through it back at the same(Might not
#  Pretend that right now what's up
#  Like, like
#  Let me nigga in my new at the very first black and all
#  Judging the land to bust tables, now
#  I ain't ashamed of y'all demise
#  My chain, my great again
#  Rap, bitches, I'mma get high yeah, it now we will be dipping in which I would lie
#  He always gotta like that green get high
#  But you are not, you down the fact you until it like I'm taught and wonder how in this journey to me
#  But I run away a muzzle
#  Let me a kind of flows,
#  And when they wonder where the club
#  I suggest you know
#  They say, yes
#  Mass choir
#  Than that was December of they notice happiness and then hit the Devil said I live, I keep a suitcase
#  We get the back again
#  Just because my rhymes
#  I read it like my sight
#  It wasn't tryna eat
#  I searched and said they wanted from me good old man it's like I'm back in women it's my eye, then gon tell him a hospital bed
#  Now some truancy
#  It feel like everybody bleed, everybody bleed, everybody knowI been killin' this, hold up, get up, you would then someone out of a year, couldn't comprehend the wrong
#  Rap, bitches, I'mma go investigating shit, alright?
#  You know me
#  Depends the vibe
#  And some more to the hustle
#  Rap, bitches, sipping sinatra from Rick Rubin, dinner plan
#  They spend your mind
#  Judging rap shit is TDEHappy birthday
